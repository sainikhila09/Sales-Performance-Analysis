# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(
    "superstore_final_dataset (1).csv",
    encoding="latin1"
)

df.head()
# Out:
#    Row_ID        Order_ID  Order_Date   Ship_Date       Ship_Mode Customer_ID  \
# 0       1  CA-2017-152156   8/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156   8/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688   12/6/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3    Sean O Donnel   Consumer  United States  Fort Lauderdale     Florida
# 4    Sean O Donnel   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
print("Rows and Columns:", df.shape)
# Out:
# Rows and Columns: (9800, 18)

# %%
print(df.columns.tolist())
# Out:
# ['Row_ID', 'Order_ID', 'Order_Date', 'Ship_Date', 'Ship_Mode', 'Customer_ID', 'Customer_Name', 'Segment', 'Country', 'City', 'State', 'Postal_Code', 'Region', 'Product_ID', 'Category', 'Sub_Category', 'Product_Name', 'Sales']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row_ID         9800 non-null   int64
#  1   Order_ID       9800 non-null   object
#  2   Order_Date     9800 non-null   object
#  3   Ship_Date      9800 non-null   object
#  4   Ship_Mode      9800 non-null   object
#  5   Customer_ID    9800 non-null   object
#  6   Customer_Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal_Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product_ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub_Category   9800 non-null   object
#  16  Product_Name   9800 non-null   object
# ...

# %%
df.describe()
# Out:
#             Row_ID   Postal_Code         Sales
# count  9800.000000   9789.000000   9800.000000
# mean   4900.500000  55273.322403    230.769059
# std    2829.160653  32041.223413    626.651875
# min       1.000000   1040.000000      0.444000
# 25%    2450.750000  23223.000000     17.248000
# 50%    4900.500000  58103.000000     54.490000
# 75%    7350.250000  90008.000000    210.605000
# max    9800.000000  99301.000000  22638.480000

# %%
df.dtypes
# Out:
# Row_ID             int64
# Order_ID          object
# Order_Date        object
# Ship_Date         object
# Ship_Mode         object
# Customer_ID       object
# Customer_Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal_Code      float64
# Region            object
# Product_ID        object
# Category          object
# Sub_Category      object
# Product_Name      object
# Sales            float64
# dtype: object

# %%
print(df.isnull().sum())
# Out:
# Row_ID            0
# Order_ID          0
# Order_Date        0
# Ship_Date         0
# Ship_Mode         0
# Customer_ID       0
# Customer_Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal_Code      11
# Region            0
# Product_ID        0
# Category          0
# Sub_Category      0
# Product_Name      0
# Sales             0
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
print("Mean")
print(df.mean(numeric_only=True))

print("\nMedian")
print(df.median(numeric_only=True))

print("\nMode")
print(df.mode().iloc[0])
# Out:
# Mean
# Row_ID          4900.500000
# Postal_Code    55273.322403
# Sales            230.769059
# dtype: float64
#
# Median
# Row_ID          4900.50
# Postal_Code    58103.00
# Sales             54.49
# dtype: float64
#
# Mode
# Row_ID                         1
# Order_ID          CA-2018-100111
# Order_Date              5/9/2017
# Ship_Date             26/09/2018
# Ship_Mode         Standard Class
# Customer_ID             WB-21850
# Customer_Name      William Brown
# Segment                 Consumer
# Country            United States
# City               New York City
# State                 California
# Postal_Code              10035.0
# Region                      West
# Product_ID       OFF-PA-10001970
# Category         Office Supplies
# Sub_Category             Binders
# Product_Name     Staple envelope
# Sales                      12.96
# Name: 0, dtype: object

# %%
df["Order_Date"] = pd.to_datetime(
    df["Order_Date"],
    dayfirst=True
)

df["Ship_Date"] = pd.to_datetime(
    df["Ship_Date"],
    dayfirst=True
)

df.head()
# Out:
#    Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 0       1  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 1       2  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 2       3  CA-2017-138688 2017-06-12 2017-06-16    Second Class    DV-13045
# 3       4  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
# 4       5  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3    Sean O Donnel   Consumer  United States  Fort Lauderdale     Florida
# 4    Sean O Donnel   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
df["Year"] = df["Order_Date"].dt.year
df["Month"] = df["Order_Date"].dt.month_name()

df.head()
# Out:
#    Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 0       1  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 1       2  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 2       3  CA-2017-138688 2017-06-12 2017-06-16    Second Class    DV-13045
# 3       4  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
# 4       5  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3    Sean O Donnel   Consumer  United States  Fort Lauderdale     Florida
# 4    Sean O Donnel   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
#Sales by Category
category_sales = df.groupby("Category")["Sales"].sum()

plt.figure(figsize=(7,5))

category_sales.plot(kind="bar")

plt.title("Sales by Category")
plt.xlabel("Category")
plt.ylabel("Total Sales")

plt.show()

# %%
#Sales by Region
region_sales = df.groupby("Region")["Sales"].sum()

plt.figure(figsize=(7,5))

region_sales.plot(kind="bar")

plt.title("Sales by Region")
plt.xlabel("Region")
plt.ylabel("Total Sales")

plt.show()

# %%
#Sales by Segment
segment_sales = df.groupby("Segment")["Sales"].sum()

plt.figure(figsize=(7,5))

segment_sales.plot(kind="bar")

plt.title("Sales by Customer Segment")
plt.xlabel("Segment")
plt.ylabel("Total Sales")

plt.show()

# %%
#Monthly Sales Trend
monthly_sales = df.groupby("Month")["Sales"].sum()

month_order = [
    "January","February","March","April","May","June",
    "July","August","September","October","November","December"
]

monthly_sales = monthly_sales.reindex(month_order)

plt.figure(figsize=(10,5))

plt.plot(monthly_sales.index, monthly_sales.values, marker="o")

plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Sales")

plt.xticks(rotation=45)

plt.show()

# %%
#Top 10 States by Sales
state_sales = df.groupby("State")["Sales"].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(10,5))

state_sales.plot(kind="bar")

plt.title("Top 10 States by Sales")
plt.xlabel("State")
plt.ylabel("Sales")

plt.show()

# %%
#Top 10 Products by Sales
product_sales = df.groupby("Product_Name")["Sales"].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(10,5))

product_sales.plot(kind="bar")

plt.title("Top 10 Products by Sales")
plt.xlabel("Product")
plt.ylabel("Sales")

plt.xticks(rotation=90)

plt.show()

# %%
print(df.columns.tolist())
# Out:
# ['Row_ID', 'Order_ID', 'Order_Date', 'Ship_Date', 'Ship_Mode', 'Customer_ID', 'Customer_Name', 'Segment', 'Country', 'City', 'State', 'Postal_Code', 'Region', 'Product_ID', 'Category', 'Sub_Category', 'Product_Name', 'Sales', 'Year', 'Month']

# %%
print("Total Sales:", df["Sales"].sum())
# Out:
# Total Sales: 2261536.7827000003

# %%
# Key Performance Indicators

total_revenue = df["Sales"].sum()
average_order_value = df["Sales"].mean()
total_orders = df["Order_ID"].nunique()

print(" KEY PERFORMANCE INDICATORS ")
print(f"Total Revenue       : ₹{total_revenue:,.2f}")
print(f"Average Order Value : ₹{average_order_value:,.2f}")
print(f"Total Orders        : {total_orders}")
# Out:
#  KEY PERFORMANCE INDICATORS
# Total Revenue       : ₹2,261,536.78
# Average Order Value : ₹230.77
# Total Orders        : 4922

# %% [markdown]
# ## Key Performance Indicators (KPIs)
#
# The following KPIs were calculated from the available sales dataset:
#
# - Total Revenue
# - Average Order Value (AOV)
# - Total Orders
#
# **Note:** Profit Margin and Conversion Metrics were not calculated because the dataset does not contain Profit, Cost, or Conversion-related information.

# %%
print(df.groupby("Category")["Sales"].sum())
# Out:
# Category
# Furniture          728658.5757
# Office Supplies    705422.3340
# Technology         827455.8730
# Name: Sales, dtype: float64

# %%
print(df.groupby("Region")["Sales"].sum())
# Out:
# Region
# Central    492646.9132
# East       669518.7260
# South      389151.4590
# West       710219.6845
# Name: Sales, dtype: float64

# %%
print(df.groupby("Segment")["Sales"].sum())
# Out:
# Segment
# Consumer       1.148061e+06
# Corporate      6.884941e+05
# Home Office    4.249822e+05
# Name: Sales, dtype: float64

# %%
df.to_csv("Sales_Performance_Processed.csv", index=False)

print("Processed dataset saved successfully!")
# Out:
# Processed dataset saved successfully!

# %% [markdown]
# # **Key Findings**
#
# 1. Technology and Office Supplies generated a significant share of total sales.
#
# 2. Sales performance varied across different regions, highlighting geographical differences in demand.
#
# 3. Monthly sales showed fluctuations throughout the year, indicating seasonal purchasing patterns.
#
# 4. Consumer, Corporate, and Home Office segments contributed differently to overall sales.
#
# 5. Certain products consistently generated higher sales than others, making them important contributors to revenue.

# %% [markdown]
# # **Recommendations**
#
# 1. Increase inventory for high-performing products.
#
# 2. Focus marketing campaigns on regions with strong sales performance.
#
# 3. Improve promotional strategies during months with lower sales.
#
# 4. Develop customer loyalty programs for high-value customer segments.
#
# 5. Monitor product performance regularly to optimize inventory and maximize revenue.
